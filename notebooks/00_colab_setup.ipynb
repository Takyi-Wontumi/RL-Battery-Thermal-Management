# %% [markdown]
# # 00 — Colab Setup
#
# Run this notebook **once** before any training notebook.
# It mounts Google Drive, installs dependencies, verifies GPU, and confirms the
# environment loads correctly.
#
# **Runtime → Change runtime type → T4 GPU** (recommended before training).

# %% [markdown]
# ## Step 1 — Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Step 2 — Locate the Project
#
# **Choose ONE option below. Comment out the other.**

# %%
# ── OPTION A: Clone from GitHub (run once, then switch to Option B) ──────────
# Replace YOUR_USERNAME with your GitHub username.
# !git clone https://github.com/YOUR_USERNAME/RL-Battery-Thermal-Management.git
# %cd RL-Battery-Thermal-Management

# ── OPTION B: Use existing Drive folder ──────────────────────────────────────
# Adjust the path if your Drive folder has a different name.
# %cd /content/drive/MyDrive/RL-Battery-Thermal-Management

import os
print('Working directory:', os.getcwd())
print('Contents:', os.listdir('.'))

# %% [markdown]
# ## Step 3 — Install Dependencies

# %%
# !pip install -q -r requirements.txt
print('Dependencies installed.')

# %% [markdown]
# ## Step 4 — Verify GPU

# %%
import torch

print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
    print('VRAM:', round(torch.cuda.get_device_properties(0).total_memory / 1e9, 1), 'GB')
else:
    print('Running on CPU — training will be slow.')
    print('Go to Runtime → Change runtime type → GPU.')

# %% [markdown]
# ## Step 5 — Fix Python Path

# %%
import os
import sys

PROJECT_ROOT = os.getcwd()
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print('Project root:', PROJECT_ROOT)

# %% [markdown]
# ## Step 6 — Test Imports

# %%
from envs.battery_pack_thermal_env_3d import BatteryPackThermalEnv3D
from configs.pack_config import CellConfig, PackConfig

env = BatteryPackThermalEnv3D()
obs, info = env.reset()

print('Environment loaded successfully.')
print('Observation shape:', obs.shape)
print('Action space:     ', env.action_space)
print('Observation space:', env.observation_space)

env.close()
print('\nSetup complete — ready to train.')
